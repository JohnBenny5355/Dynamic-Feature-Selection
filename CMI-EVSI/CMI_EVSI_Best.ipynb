# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append('/content/drive/MyDrive')

# %%
from sklearn.preprocessing import StandardScaler
import seaborn as sns
import matplotlib as mpl

# %% [markdown]
# #Standard imports

# %%
# !pip install pytorch_lightning
import torch
import numpy as np
import torch.nn as nn
import dynamic_selection as ds
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader,Subset, TensorDataset
from torchmetrics import Accuracy, AUROC
from dynamic_selection import MaskingPretrainer, GreedyDynamicSelection,BaseModel
import pandas as pd
# Out:
# Requirement already satisfied: pytorch_lightning in /usr/local/lib/python3.10/dist-packages (2.0.8)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.23.5)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2.0.1+cu118)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.66.1)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (2023.6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (1.1.1)
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (23.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (4.7.1)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch_lightning) (0.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch_lightning) (3.8.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (3.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->pytorch_lightning) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch_lightning) (3.27.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11.0->pytorch_lightning) (16.0.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->pytorch_lightning) (2.1.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>2021.06.0->pytorch_lightning) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->pytorch_lightning) (1.3.0)

# %% [markdown]
# #Dataset

# %%
# Load dataset.
dataset = ds.data.load_spam()
d_in = dataset.input_size    # 57
d_out = dataset.output_size  # 2
# Normalize and split dataset.
mean = dataset.tensors[0].mean(dim=0)
dataset.tensors = (dataset.tensors[0] - mean, dataset.tensors[1])
train_dataset, val_dataset, test_dataset = ds.data.data_split(dataset)

# %%
# Prepare dataloaders.
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, pin_memory=True, drop_last=True)
val_loader = DataLoader(val_dataset, batch_size=1024, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=1024, pin_memory=True)

# %% [markdown]
# #Networks

# %%
# Set up networks
hidden = 128
dropout = 0.3

predictor = nn.Sequential(
    nn.Linear(2 * d_in, hidden),
    nn.ReLU(),
    nn.Dropout(dropout),
    nn.Linear(hidden, hidden),
    nn.ReLU(),
    nn.Dropout(dropout),
    nn.Linear(hidden, d_out))

selector = nn.Sequential(
    nn.Linear(2 * d_in, hidden),
    nn.ReLU(),
    nn.Dropout(dropout),
    nn.Linear(hidden, hidden),
    nn.ReLU(),
    nn.Dropout(dropout),
    nn.Linear(hidden, d_in))

# %%
# Pretrain predictor.
mask_layer = ds.utils.MaskLayer(append=True)
pretrain = MaskingPretrainer(predictor, mask_layer).cuda()
pretrain.fit(
    train_loader,
    val_loader,
    lr=1e-3,
    nepochs=15,#100
    loss_fn=nn.CrossEntropyLoss(),
    verbose=True)
# Out:
# --------Epoch 1--------
# Val loss = 1.0461
#
# --------Epoch 2--------
# Val loss = 0.9948
#
# --------Epoch 3--------
# Val loss = 0.9821
#
# --------Epoch 4--------
# Val loss = 0.9756
#
# --------Epoch 5--------
# Val loss = 0.9767
#
# --------Epoch 6--------
# Val loss = 0.9921
#
# --------Epoch 7--------
# Val loss = 0.9746
#
# --------Epoch 8--------
# Val loss = 0.9786
#
# --------Epoch 9--------
# Val loss = 0.9683
#
# --------Epoch 10--------
# Val loss = 0.9746
#
# --------Epoch 11--------
# Val loss = 0.9875
#
# --------Epoch 12--------
# Val loss = 0.9771
#
# Epoch 00012: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 13--------
# Val loss = 0.9575
#
# --------Epoch 14--------
# Val loss = 0.9535
#
# --------Epoch 15--------
# Val loss = 0.9555

# %%
# Train selector and predictor jointly.
gdfs = GreedyDynamicSelection(selector, predictor, mask_layer).cuda()
gdfs.fit(
    train_loader,
    val_loader,
    lr=1e-3,
    nepochs=15,#250
    start_temp=0.3,
    temp_steps=1,
    max_features=35,
    loss_fn=nn.CrossEntropyLoss(),
    verbose=True)
# Out:
# Starting training with temp = 0.3000
#
# epoch is 0
#
# --------Epoch 1 (1 total)--------
# Val loss = 0.4587, Zero-temp loss = 0.4586
#
# epoch is 1
#
# --------Epoch 2 (2 total)--------
# Val loss = 0.4591, Zero-temp loss = 0.4591
#
# epoch is 2
#
# --------Epoch 3 (3 total)--------
# Val loss = 0.4492, Zero-temp loss = 0.4491
#
# epoch is 3
#
# --------Epoch 4 (4 total)--------
# Val loss = 0.4376, Zero-temp loss = 0.4371
#
# epoch is 4
#
# --------Epoch 5 (5 total)--------
# Val loss = 0.4582, Zero-temp loss = 0.4578
#
# epoch is 5
#
# --------Epoch 6 (6 total)--------
# Val loss = 0.4389, Zero-temp loss = 0.4388
#
# epoch is 6
#
# --------Epoch 7 (7 total)--------
# Val loss = 0.4333, Zero-temp loss = 0.4330
#
# epoch is 7
#
# --------Epoch 8 (8 total)--------
# Val loss = 0.3826, Zero-temp loss = 0.3825
#
# epoch is 8
#
# --------Epoch 9 (9 total)--------
# Val loss = 0.4142, Zero-temp loss = 0.4139
#
# epoch is 9
#
# --------Epoch 10 (10 total)--------
# Val loss = 0.3803, Zero-temp loss = 0.3803
#
# epoch is 10
#
# --------Epoch 11 (11 total)--------
# Val loss = 0.3981, Zero-temp loss = 0.3979
#
# epoch is 11
#
# --------Epoch 12 (12 total)--------
# Val loss = 0.3550, Zero-temp loss = 0.3550
#
# epoch is 12
#
# --------Epoch 13 (13 total)--------
# Val loss = 0.3556, Zero-temp loss = 0.3556
#
# epoch is 13
#
# --------Epoch 14 (14 total)--------
# Val loss = 0.3410, Zero-temp loss = 0.3409
#
# epoch is 14
#
# --------Epoch 15 (15 total)--------
# Val loss = 0.3318, Zero-temp loss = 0.3318
#
# Stopping temp = 0.3000 at epoch 15

# %% [markdown]
# # Evaluate performance
#
# - AUROC and top-1 accuracy increase quickly with the number of selections
# - Performance can often be improved by increasing the `patience` parameter, or increasing the number of temperature steps (`temp_steps`)

# %%
# For saving results.
num_features = list(range(1, 11)) + list(range(15, 30, 5))
auroc_list = []
acc_list = []

# Metrics (softmax is applied automatically in recent versions of torchmetrics).
auroc_metric = lambda pred, y: AUROC(task='multiclass', num_classes=d_out)(pred.softmax(dim=1), y)
acc_metric = Accuracy(task='multiclass', num_classes=d_out)

# Evaluate.
for num in num_features:
    auroc, acc = gdfs.evaluate(test_loader, num, (auroc_metric, acc_metric))
    auroc_list.append(auroc)
    acc_list.append(acc)
    print(f'Num = {num}, AUROC = {100*auroc:.2f}, Acc = {100*acc:.2f}')
# Out:
# Num = 1, AUROC = 83.04, Acc = 64.27
# Num = 2, AUROC = 93.03, Acc = 78.76
# Num = 3, AUROC = 93.91, Acc = 80.16
# Num = 4, AUROC = 95.00, Acc = 83.64
# Num = 5, AUROC = 95.06, Acc = 83.29
# Num = 6, AUROC = 96.57, Acc = 85.43
# Num = 7, AUROC = 97.35, Acc = 86.01
# Num = 8, AUROC = 97.41, Acc = 85.99
# Num = 9, AUROC = 97.21, Acc = 85.48
# Num = 10, AUROC = 97.85, Acc = 87.23
# Num = 15, AUROC = 98.43, Acc = 89.31
# Num = 20, AUROC = 97.90, Acc = 87.27
# Num = 25, AUROC = 97.88, Acc = 87.79

# %%
# Plot results
fig, axarr = plt.subplots(1, 2, figsize=(18, 6))

# AUROC
plt.sca(axarr[0])
plt.plot(num_features, auroc_list, marker='o')
plt.xlabel('# Features', fontsize=16)
plt.ylabel('AUROC', fontsize=16)
plt.title('AUROC vs. Feature Budget', fontsize=18)
plt.tick_params(labelsize=14)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

# Accuracy
plt.sca(axarr[1])
plt.plot(num_features, acc_list, marker='o')
plt.xlabel('# Features', fontsize=16)
plt.ylabel('Accuracy', fontsize=16)
plt.title('Accuracy vs. Feature Budget', fontsize=18)
plt.tick_params(labelsize=14)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot selections

# %%
# Generate selections for entire test set.
num_features = range(1, 20)
p_list = []

#for num in num_features:
print(str(20)+'\n')
x, y = ds.data.get_xy(test_dataset)
x_np=x.numpy()
x_test_df=pd.DataFrame(x_np)
pred, x_masked, m = gdfs(x.cuda(), max_features=20)
p = m.mean(dim=0)
print('\n P is \n')
p_list.append(p.cpu().numpy())
print(p)
print(p_list)
# Out:
# 20
#
#
#  P is
#
# tensor([0.3092, 1.0000, 0.1029, 0.8412, 1.0000, 0.0000, 0.4405, 1.0000, 1.0000,
#         0.9995, 0.6243, 1.0000, 0.3229, 1.0000, 0.9864, 0.0000, 0.7719, 1.0000,
#         0.4576, 0.0000, 0.7930, 1.0000, 0.0000, 0.8952, 0.1603, 0.0000, 0.4670,
#         0.0000, 0.9979, 0.1317, 0.8625, 1.0000, 0.0000, 0.8359],
#        device='cuda:0')
# [array([0.30921012, 0.99999994, 0.10286351, 0.84121186, 0.99999994,
#        0.        , 0.4405447 , 0.99999994, 0.99999994, 0.99949116,
#        0.6243245 , 0.99999994, 0.32286096, 0.99999994, 0.98641884,
#        0.        , 0.77187026, 0.99999994, 0.4576175 , 0.        ,
#        0.7930338 , 0.99999994, 0.        , 0.8951711 , 0.16031034,
#        0.        , 0.4670094 , 0.        , 0.997932  , 0.1317367 ,
#        0.8624862 , 0.99999994, 0.        , 0.8359066 ], dtype=float32)]

# %% [markdown]
# # Get Sensors

# %%
sensors_index=np.array(p_list)
sorted_indices = np.flip(np.argsort(sensors_index))
sensors=[]
for i in range(0,20):
  sensors = np.append(sensors, dataset.features[sorted_indices[0][i]])
sensors=sensors.tolist()
sorted_indices=sorted_indices[0][0:20].tolist()
sensors
# Out:
# ['<Cltch2State>',
#  '<BattSoc>',
#  '<ThrPosPct>',
#  '<IntkVlvLift>',
#  'TransGear',
#  '<BattV>',
#  '<Acc>',
#  'sample',
#  'IntkVlvLiftCmd',
#  '<TransGear>',
#  'BattCrnt:1',
#  '<WgAreaPct>',
#  'Cltch1Cmd',
#  'MotPwrMech:1',
#  '<xdot>',
#  'FuelFlw',
#  '<Chrg>',
#  '<VarCompRatioPos>',
#  '<EngSpd>',
#  'StartCmd']

# %% [markdown]
# #calculate Prior

# %%
cost_false_positive = 2
cost_false_negative = 4

x , y_train_tensor = ds.data.get_xy(train_dataset)
x_np=x.numpy()
x_train_df=pd.DataFrame.from_records(x_np)
unique_elements, counts = torch.unique(y, return_counts=True)
for i in range(unique_elements.size(0)):
  if unique_elements[i]==0:
    non_fault = counts[i]
    break
total = torch.sum(counts)

x , y_val_tensor = ds.data.get_xy(val_dataset)
x_np=x.numpy()
x_cv_df=pd.DataFrame.from_records(x_np)
unique_elements, counts = torch.unique(y, return_counts=True)
for i in range(unique_elements.size(0)):
  if unique_elements[i]==0:
    non_fault += counts[i]
total += torch.sum(counts)

P_present = non_fault/total
P_absent = 1 - P_present

# %% [markdown]
# #Utility Functions

# %%
def feature_remover(features_names):
    # remove a list of features from x

    dimension = dict()

    # row dimension
    dimension['train_row'] = len(x_train_df)
    dimension['test_row'] = len(x_test_df)
    dimension['cv_row'] = len(x_cv_df)

    # create a copy so we don't change the original dataframe
    x_train_masked_df = x_train_df.copy()
    x_test_masked_df = x_test_df.copy()
    x_cv_masked_df = x_cv_df.copy()

    for feature in features_names:
        x_train_masked_df.drop([feature], axis = 1, inplace = True)
        x_test_masked_df.drop([feature], axis = 1, inplace = True)
        x_cv_masked_df.drop([feature], axis = 1, inplace = True)

    # column dimension
    dimension['train_col'] = x_train_masked_df.shape[1]
    dimension['test_col'] = x_test_masked_df.shape[1]
    dimension['cv_col'] = x_cv_masked_df.shape[1]

    standard_scalar = StandardScaler()
    x_train_masked_df = standard_scalar.fit_transform(x_train_masked_df)
    x_test_masked_df = standard_scalar.transform(x_test_masked_df)
    x_cv_masked_df = standard_scalar.transform(x_cv_masked_df)


    x_train = np.resize(x_train_masked_df, (dimension['train_row'], dimension['train_col'], 1))
    x_test = np.resize(x_test_masked_df, (dimension['test_row'], dimension['test_col'], 1))
    x_cv = np.resize(x_cv_masked_df, (dimension['cv_row'], dimension['cv_col'], 1))

    return dimension, x_train, x_test, x_cv

# %%
# helper function to calculate probability of correctly giving signal when present
def get_signal_present(prediction, ground_truth):
    present_index = list()
    for i in range(len(ground_truth)):
        if ground_truth[i] == 0:
            present_index.append(i)

    counter = 0
    for index in present_index:
        if prediction[index] == 0:
            counter += 1

    return counter/len(present_index)

# helper function to calculate probability of correctly giving signal when present
# there should be a more generic way using operator module to merge this with the one above.
def get_no_signal_absent(prediction, ground_truth):
    absent_index = list()
    for i in range(len(ground_truth)):
        if ground_truth[i] != 0:
            absent_index.append(i)

    counter = 0
    for index in absent_index:
        if prediction[index] != 0:
            counter += 1
    return counter/len(absent_index)

# %%
def get_expected_cost(prediction,GT_tensor):
  # get P(signal|present) and P(no signal|absent)
    ground_truth = GT_tensor.tolist()
    P_signal_present = get_signal_present(prediction, ground_truth)
    P_no_signal_absent = get_no_signal_absent(prediction, ground_truth)
    P_signal_absent = 1 - P_no_signal_absent
    P_no_signal_present = 1 - P_signal_present

  # get P(signal)
    P_signal = P_present * P_signal_present + P_absent * P_signal_absent
    P_no_signal = 1 - P_signal

  # bayesian probability
    P_absent_signal = (P_signal_absent * P_absent) / P_signal
    P_present_signal = (P_signal_present * P_present) / P_signal
    P_absent_no_signal = (P_no_signal_absent * P_absent) / P_no_signal
    P_present_no_signal = (P_no_signal_present * P_present) / P_no_signal

  #calculate the evoi
    evoi = P_signal * min(cost_false_positive * P_absent_signal, cost_false_negative * P_present_signal) + P_no_signal * min(cost_false_positive * P_absent_no_signal, cost_false_negative * P_present_no_signal)

    return evoi

# %%
def plot_dict(dictionary):
    x, y = [], []
    for key, value in dictionary.items():
        x.append(key)
        y.append(value)
    return x, y

# %% [markdown]
# #Train with all selected signals

# %%
predictor_Base = nn.Sequential(
    nn.Linear( 20, hidden),
    nn.ReLU(),
    nn.Dropout(dropout),
    nn.Linear(hidden, hidden),
    nn.ReLU(),
    nn.Dropout(dropout),
    nn.Linear(hidden, 3))

# %%
_ , y = ds.data.get_xy(test_dataset)
base_prediction = (pred.cpu()).detach().numpy()
base_prediction = np.argmax(base_prediction, axis=-1)
base_cost = get_expected_cost(base_prediction,y).item()

# %% [markdown]
# #Train without Selected Signals

# %%
predictor_EVSI = nn.Sequential(
    nn.Linear( 19, hidden),
    nn.ReLU(),
    nn.Dropout(dropout),
    nn.Linear(hidden, hidden),
    nn.ReLU(),
    nn.Dropout(dropout),
    nn.Linear(hidden, 3))

# %%
upper_dict = dict()
column_names=(dataset.features).tolist()
x_train_df.columns=column_names
x_test_df.columns=column_names
x_cv_df.columns=column_names
for indice,sensor in zip(sorted_indices,sensors):
    remove_indices = sorted_indices.copy()
    remove_indices.remove(indice)

    #dimension, x_train, x_test, x_cv = feature_remover(features_names = remove_sensors)
    x, y = ds.data.get_xy(train_dataset)
    selected_columns = torch.index_select(x, 1, torch.tensor(remove_indices))
    dataset_train_EVSI = TensorDataset(selected_columns,y)
    dataloader_train = DataLoader(dataset_train_EVSI, batch_size=128, shuffle=False, pin_memory=True, drop_last=True)

    x, y = ds.data.get_xy(val_dataset)
    selected_columns = torch.index_select(x, 1, torch.tensor(remove_indices))
    dataset_val_EVSI = TensorDataset(selected_columns,y)
    dataloader_val = DataLoader(dataset_val_EVSI, batch_size=128, shuffle=False)

    #dataset_test_EVSI = TensorDataset(torch.from_numpy(x_cv))
    #dataloader_test = DataLoader(dataset_test_EVSI, batch_size=128, shuffle=False)

    model_EVSI = BaseModel(predictor_EVSI).cuda()
    model_EVSI.fit(dataloader_train,dataloader_val,lr=1e-3,nepochs=15,loss_fn=nn.CrossEntropyLoss(),verbose=True)

    x , y = ds.data.get_xy(test_dataset)
    selected_columns = torch.index_select(x, 1, torch.tensor(remove_indices))
    #dataset_test_EVSI = TensorDataset(selected_columns,y)
    #dataloader_val = DataLoader(dataset_val_EVSI, batch_size=128, shuffle=False)
    upper_prediction1 = model_EVSI(selected_columns.cuda())
    upper_prediction = (upper_prediction1.cpu()).detach().numpy()
    upper_prediction = np.argmax(upper_prediction, axis=-1)
    upper_dict[sensor] = get_expected_cost(upper_prediction,y)
# Out:
# --------Epoch 1--------
# Val loss = 0.5606
#
# --------Epoch 2--------
# Val loss = 0.5110
#
# --------Epoch 3--------
# Val loss = 0.4893
#
# --------Epoch 4--------
# Val loss = 0.4761
#
# --------Epoch 5--------
# Val loss = 0.4672
#
# --------Epoch 6--------
# Val loss = 0.4517
#
# --------Epoch 7--------
# Val loss = 0.4194
#
# --------Epoch 8--------
# Val loss = 0.4057
#
# --------Epoch 9--------
# Val loss = 0.3911
#
# --------Epoch 10--------
# Val loss = 0.3933
#
# --------Epoch 11--------
# Val loss = 0.3700
#
# --------Epoch 12--------
# Val loss = 0.3815
#
# --------Epoch 13--------
# Val loss = 0.4139
#
# --------Epoch 14--------
# Val loss = 0.3847
#
# Epoch 00014: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 15--------
# Val loss = 0.2928
#
# --------Epoch 1--------
# Val loss = 0.5213
#
# --------Epoch 2--------
# Val loss = 0.5153
#
# --------Epoch 3--------
# Val loss = 0.5049
#
# --------Epoch 4--------
# Val loss = 0.5075
#
# --------Epoch 5--------
# Val loss = 0.4687
#
# --------Epoch 6--------
# Val loss = 0.4295
#
# --------Epoch 7--------
# Val loss = 0.4488
#
# --------Epoch 8--------
# Val loss = 0.4328
#
# --------Epoch 9--------
# Val loss = 0.3960
#
# --------Epoch 10--------
# Val loss = 0.3890
#
# --------Epoch 11--------
# Val loss = 0.4202
#
# --------Epoch 12--------
# Val loss = 0.3697
#
# --------Epoch 13--------
# Val loss = 0.3612
#
# --------Epoch 14--------
# Val loss = 0.4092
#
# --------Epoch 15--------
# Val loss = 0.3813
#
# --------Epoch 1--------
# Val loss = 0.4914
#
# --------Epoch 2--------
# Val loss = 0.4220
#
# --------Epoch 3--------
# Val loss = 0.3872
#
# --------Epoch 4--------
# Val loss = 0.3635
#
# --------Epoch 5--------
# Val loss = 0.3700
#
# --------Epoch 6--------
# Val loss = 0.3686
#
# --------Epoch 7--------
# Val loss = 0.3899
#
# Epoch 00007: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 8--------
# Val loss = 0.3066
#
# --------Epoch 9--------
# Val loss = 0.3004
#
# --------Epoch 10--------
# Val loss = 0.2875
#
# --------Epoch 11--------
# Val loss = 0.2682
#
# --------Epoch 12--------
# Val loss = 0.2674
#
# --------Epoch 13--------
# Val loss = 0.2458
#
# --------Epoch 14--------
# Val loss = 0.2402
#
# --------Epoch 15--------
# Val loss = 0.2421
#
# --------Epoch 1--------
# Val loss = 0.3792
#
# --------Epoch 2--------
# Val loss = 0.3893
#
# --------Epoch 3--------
# Val loss = 0.3679
#
# --------Epoch 4--------
# Val loss = 0.3471
#
# --------Epoch 5--------
# Val loss = 0.3569
#
# --------Epoch 6--------
# Val loss = 0.3525
#
# --------Epoch 7--------
# Val loss = 0.3590
#
# Epoch 00007: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 8--------
# Val loss = 0.2834
#
# --------Epoch 9--------
# Val loss = 0.2811
#
# --------Epoch 10--------
# Val loss = 0.2770
#
# --------Epoch 11--------
# Val loss = 0.2638
#
# --------Epoch 12--------
# Val loss = 0.2518
#
# --------Epoch 13--------
# Val loss = 0.2517
#
# --------Epoch 14--------
# Val loss = 0.2530
#
# --------Epoch 15--------
# Val loss = 0.2465
#
# --------Epoch 1--------
# Val loss = 0.3335
#
# --------Epoch 2--------
# Val loss = 0.3458
#
# --------Epoch 3--------
# Val loss = 0.3636
#
# --------Epoch 4--------
# Val loss = 0.3465
#
# Epoch 00004: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 5--------
# Val loss = 0.2778
#
# --------Epoch 6--------
# Val loss = 0.2760
#
# --------Epoch 7--------
# Val loss = 0.2702
#
# --------Epoch 8--------
# Val loss = 0.2655
#
# --------Epoch 9--------
# Val loss = 0.2591
#
# --------Epoch 10--------
# Val loss = 0.2527
#
# --------Epoch 11--------
# Val loss = 0.2633
#
# --------Epoch 12--------
# Val loss = 0.2540
#
# --------Epoch 13--------
# Val loss = 0.2489
#
# --------Epoch 14--------
# Val loss = 0.2485
#
# --------Epoch 15--------
# Val loss = 0.2423
#
# --------Epoch 1--------
# Val loss = 0.4291
#
# --------Epoch 2--------
# Val loss = 0.4046
#
# --------Epoch 3--------
# Val loss = 0.3517
#
# --------Epoch 4--------
# Val loss = 0.3999
#
# --------Epoch 5--------
# Val loss = 0.3545
#
# --------Epoch 6--------
# Val loss = 0.4071
#
# Epoch 00006: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 7--------
# Val loss = 0.2870
#
# --------Epoch 8--------
# Val loss = 0.2936
#
# --------Epoch 9--------
# Val loss = 0.2721
#
# --------Epoch 10--------
# Val loss = 0.2707
#
# --------Epoch 11--------
# Val loss = 0.2638
#
# --------Epoch 12--------
# Val loss = 0.2611
#
# --------Epoch 13--------
# Val loss = 0.2617
#
# --------Epoch 14--------
# Val loss = 0.2613
#
# --------Epoch 15--------
# Val loss = 0.2612
#
# Epoch 00015: reducing learning rate of group 0 to 4.0000e-05.
# --------Epoch 1--------
# Val loss = 0.3910
#
# --------Epoch 2--------
# Val loss = 0.3563
#
# --------Epoch 3--------
# Val loss = 0.3466
#
# --------Epoch 4--------
# Val loss = 0.3393
#
# --------Epoch 5--------
# Val loss = 0.3323
#
# --------Epoch 6--------
# Val loss = 0.3241
#
# --------Epoch 7--------
# Val loss = 0.3344
#
# --------Epoch 8--------
# Val loss = 0.3239
#
# --------Epoch 9--------
# Val loss = 0.3475
#
# --------Epoch 10--------
# Val loss = 0.3658
#
# --------Epoch 11--------
# Val loss = 0.3298
#
# Epoch 00011: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 12--------
# Val loss = 0.2813
#
# --------Epoch 13--------
# Val loss = 0.2787
#
# --------Epoch 14--------
# Val loss = 0.2675
#
# --------Epoch 15--------
# Val loss = 0.2740
#
# --------Epoch 1--------
# Val loss = 0.5560
#
# --------Epoch 2--------
# Val loss = 0.5778
#
# --------Epoch 3--------
# Val loss = 0.5575
#
# --------Epoch 4--------
# Val loss = 0.5489
#
# --------Epoch 5--------
# Val loss = 0.5507
#
# --------Epoch 6--------
# Val loss = 0.5633
#
# --------Epoch 7--------
# Val loss = 0.5449
#
# --------Epoch 8--------
# Val loss = 0.5563
#
# --------Epoch 9--------
# Val loss = 0.5398
#
# --------Epoch 10--------
# Val loss = 0.5410
#
# --------Epoch 11--------
# Val loss = 0.5286
#
# --------Epoch 12--------
# Val loss = 0.5418
#
# --------Epoch 13--------
# Val loss = 0.5379
#
# --------Epoch 14--------
# Val loss = 0.5440
#
# Epoch 00014: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 15--------
# Val loss = 0.5111
#
# --------Epoch 1--------
# Val loss = 0.4366
#
# --------Epoch 2--------
# Val loss = 0.3866
#
# --------Epoch 3--------
# Val loss = 0.3630
#
# --------Epoch 4--------
# Val loss = 0.3512
#
# --------Epoch 5--------
# Val loss = 0.3833
#
# --------Epoch 6--------
# Val loss = 0.3397
#
# --------Epoch 7--------
# Val loss = 0.3374
#
# --------Epoch 8--------
# Val loss = 0.3223
#
# --------Epoch 9--------
# Val loss = 0.3364
#
# --------Epoch 10--------
# Val loss = 0.3308
#
# --------Epoch 11--------
# Val loss = 0.3373
#
# Epoch 00011: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 12--------
# Val loss = 0.2912
#
# --------Epoch 13--------
# Val loss = 0.2705
#
# --------Epoch 14--------
# Val loss = 0.2633
#
# --------Epoch 15--------
# Val loss = 0.2676
#
# --------Epoch 1--------
# Val loss = 0.3285
#
# --------Epoch 2--------
# Val loss = 0.3107
#
# --------Epoch 3--------
# Val loss = 0.3342
#
# --------Epoch 4--------
# Val loss = 0.3336
#
# --------Epoch 5--------
# Val loss = 0.3071
#
# --------Epoch 6--------
# Val loss = 0.3421
#
# --------Epoch 7--------
# Val loss = 0.3076
#
# --------Epoch 8--------
# Val loss = 0.3629
#
# Epoch 00008: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 9--------
# Val loss = 0.2982
#
# --------Epoch 10--------
# Val loss = 0.2750
#
# --------Epoch 11--------
# Val loss = 0.2659
#
# --------Epoch 12--------
# Val loss = 0.2597
#
# --------Epoch 13--------
# Val loss = 0.2536
#
# --------Epoch 14--------
# Val loss = 0.2524
#
# --------Epoch 15--------
# Val loss = 0.2442
#
# --------Epoch 1--------
# Val loss = 0.3106
#
# --------Epoch 2--------
# Val loss = 0.3251
#
# --------Epoch 3--------
# Val loss = 0.3447
#
# --------Epoch 4--------
# Val loss = 0.3111
#
# Epoch 00004: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 5--------
# Val loss = 0.2731
#
# --------Epoch 6--------
# Val loss = 0.2659
#
# --------Epoch 7--------
# Val loss = 0.2645
#
# --------Epoch 8--------
# Val loss = 0.2515
#
# --------Epoch 9--------
# Val loss = 0.2439
#
# --------Epoch 10--------
# Val loss = 0.2349
#
# --------Epoch 11--------
# Val loss = 0.2353
#
# --------Epoch 12--------
# Val loss = 0.2676
#
# --------Epoch 13--------
# Val loss = 0.2274
#
# --------Epoch 14--------
# Val loss = 0.2247
#
# --------Epoch 15--------
# Val loss = 0.2206
#
# --------Epoch 1--------
# Val loss = 0.4467
#
# --------Epoch 2--------
# Val loss = 0.4346
#
# --------Epoch 3--------
# Val loss = 0.4119
#
# --------Epoch 4--------
# Val loss = 0.4053
#
# --------Epoch 5--------
# Val loss = 0.3779
#
# --------Epoch 6--------
# Val loss = 0.4213
#
# --------Epoch 7--------
# Val loss = 0.3865
#
# --------Epoch 8--------
# Val loss = 0.3897
#
# Epoch 00008: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 9--------
# Val loss = 0.3379
#
# --------Epoch 10--------
# Val loss = 0.3170
#
# --------Epoch 11--------
# Val loss = 0.3124
#
# --------Epoch 12--------
# Val loss = 0.3021
#
# --------Epoch 13--------
# Val loss = 0.2996
#
# --------Epoch 14--------
# Val loss = 0.2917
#
# --------Epoch 15--------
# Val loss = 0.2883
#
# --------Epoch 1--------
# Val loss = 0.5250
#
# --------Epoch 2--------
# Val loss = 0.5545
#
# --------Epoch 3--------
# Val loss = 0.4925
#
# --------Epoch 4--------
# Val loss = 0.4488
#
# --------Epoch 5--------
# Val loss = 0.4422
#
# --------Epoch 6--------
# Val loss = 0.3830
#
# --------Epoch 7--------
# Val loss = 0.4032
#
# --------Epoch 8--------
# Val loss = 0.3638
#
# --------Epoch 9--------
# Val loss = 0.3580
#
# --------Epoch 10--------
# Val loss = 0.3901
#
# --------Epoch 11--------
# Val loss = 0.3661
#
# --------Epoch 12--------
# Val loss = 0.3537
#
# --------Epoch 13--------
# Val loss = 0.3586
#
# --------Epoch 14--------
# Val loss = 0.3505
#
# --------Epoch 15--------
# Val loss = 0.3488
#
# --------Epoch 1--------
# Val loss = 0.5384
#
# --------Epoch 2--------
# Val loss = 0.4694
#
# --------Epoch 3--------
# Val loss = 0.4372
#
# --------Epoch 4--------
# Val loss = 0.3839
#
# --------Epoch 5--------
# Val loss = 0.3783
#
# --------Epoch 6--------
# Val loss = 0.3705
#
# --------Epoch 7--------
# Val loss = 0.3682
#
# --------Epoch 8--------
# Val loss = 0.3824
#
# --------Epoch 9--------
# Val loss = 0.3998
#
# --------Epoch 10--------
# Val loss = 0.3581
#
# --------Epoch 11--------
# Val loss = 0.3564
#
# --------Epoch 12--------
# Val loss = 0.3513
#
# --------Epoch 13--------
# Val loss = 0.3400
#
# --------Epoch 14--------
# Val loss = 0.3228
#
# --------Epoch 15--------
# Val loss = 0.3044
#
# --------Epoch 1--------
# Val loss = 8.1266
#
# --------Epoch 2--------
# Val loss = 0.9636
#
# --------Epoch 3--------
# Val loss = 0.9277
#
# --------Epoch 4--------
# Val loss = 0.9015
#
# --------Epoch 5--------
# Val loss = 0.8905
#
# --------Epoch 6--------
# Val loss = 0.8613
#
# --------Epoch 7--------
# Val loss = 0.8211
#
# --------Epoch 8--------
# Val loss = 0.7987
#
# --------Epoch 9--------
# Val loss = 0.7765
#
# --------Epoch 10--------
# Val loss = 0.7623
#
# --------Epoch 11--------
# Val loss = 0.7416
#
# --------Epoch 12--------
# Val loss = 0.6915
#
# --------Epoch 13--------
# Val loss = 0.6820
#
# --------Epoch 14--------
# Val loss = 0.6665
#
# --------Epoch 15--------
# Val loss = 0.6663
#
# --------Epoch 1--------
# Val loss = 0.6655
#
# --------Epoch 2--------
# Val loss = 0.6648
#
# --------Epoch 3--------
# Val loss = 0.6676
#
# --------Epoch 4--------
# Val loss = 0.6478
#
# --------Epoch 5--------
# Val loss = 0.6430
#
# --------Epoch 6--------
# Val loss = 0.6587
#
# --------Epoch 7--------
# Val loss = 0.6361
#
# --------Epoch 8--------
# Val loss = 0.6495
#
# --------Epoch 9--------
# Val loss = 0.6355
#
# --------Epoch 10--------
# Val loss = 0.5978
#
# --------Epoch 11--------
# Val loss = 0.5954
#
# --------Epoch 12--------
# Val loss = 0.6340
#
# --------Epoch 13--------
# Val loss = 0.6215
#
# --------Epoch 14--------
# Val loss = 0.6252
#
# Epoch 00014: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 15--------
# Val loss = 0.5847
#
# --------Epoch 1--------
# Val loss = 0.5999
#
# --------Epoch 2--------
# Val loss = 0.6151
#
# --------Epoch 3--------
# Val loss = 0.6192
#
# --------Epoch 4--------
# Val loss = 0.6094
#
# Epoch 00004: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 5--------
# Val loss = 0.5683
#
# --------Epoch 6--------
# Val loss = 0.5653
#
# --------Epoch 7--------
# Val loss = 0.5493
#
# --------Epoch 8--------
# Val loss = 0.5417
#
# --------Epoch 9--------
# Val loss = 0.5423
#
# --------Epoch 10--------
# Val loss = 0.5413
#
# --------Epoch 11--------
# Val loss = 0.5328
#
# --------Epoch 12--------
# Val loss = 0.5342
#
# --------Epoch 13--------
# Val loss = 0.5296
#
# --------Epoch 14--------
# Val loss = 0.5349
#
# --------Epoch 15--------
# Val loss = 0.5310
#
# --------Epoch 1--------
# Val loss = 0.6040
#
# --------Epoch 2--------
# Val loss = 0.6145
#
# --------Epoch 3--------
# Val loss = 0.6064
#
# --------Epoch 4--------
# Val loss = 0.6052
#
# Epoch 00004: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 5--------
# Val loss = 0.5690
#
# --------Epoch 6--------
# Val loss = 0.5498
#
# --------Epoch 7--------
# Val loss = 0.5464
#
# --------Epoch 8--------
# Val loss = 0.5407
#
# --------Epoch 9--------
# Val loss = 0.5347
#
# --------Epoch 10--------
# Val loss = 0.5388
#
# --------Epoch 11--------
# Val loss = 0.5388
#
# --------Epoch 12--------
# Val loss = 0.5313
#
# --------Epoch 13--------
# Val loss = 0.5408
#
# --------Epoch 14--------
# Val loss = 0.5391
#
# --------Epoch 15--------
# Val loss = 0.5325
#
# Epoch 00015: reducing learning rate of group 0 to 4.0000e-05.
# --------Epoch 1--------
# Val loss = 0.6590
#
# --------Epoch 2--------
# Val loss = 0.6564
#
# --------Epoch 3--------
# Val loss = 0.6478
#
# --------Epoch 4--------
# Val loss = 0.6143
#
# --------Epoch 5--------
# Val loss = 0.6025
#
# --------Epoch 6--------
# Val loss = 0.6173
#
# --------Epoch 7--------
# Val loss = 0.5853
#
# --------Epoch 8--------
# Val loss = 0.5996
#
# --------Epoch 9--------
# Val loss = 0.6082
#
# --------Epoch 10--------
# Val loss = 0.5898
#
# Epoch 00010: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 11--------
# Val loss = 0.5709
#
# --------Epoch 12--------
# Val loss = 0.5545
#
# --------Epoch 13--------
# Val loss = 0.5499
#
# --------Epoch 14--------
# Val loss = 0.5447
#
# --------Epoch 15--------
# Val loss = 0.5444
#
# --------Epoch 1--------
# Val loss = 0.5832
#
# --------Epoch 2--------
# Val loss = 0.6223
#
# --------Epoch 3--------
# Val loss = 0.5837
#
# --------Epoch 4--------
# Val loss = 0.5953
#
# Epoch 00004: reducing learning rate of group 0 to 2.0000e-04.
# --------Epoch 5--------
# Val loss = 0.5729
#
# --------Epoch 6--------
# Val loss = 0.5461
#
# --------Epoch 7--------
# Val loss = 0.5359
#
# --------Epoch 8--------
# Val loss = 0.5303
#
# --------Epoch 9--------
# Val loss = 0.5307
#
# --------Epoch 10--------
# Val loss = 0.5337
#
# --------Epoch 11--------
# Val loss = 0.5290
#
# --------Epoch 12--------
# Val loss = 0.5379
#
# --------Epoch 13--------
# Val loss = 0.5247
#
# --------Epoch 14--------
# Val loss = 0.5262
#
# --------Epoch 15--------
# Val loss = 0.5235

# %%
upper_dict
# Out:
# {'<Cltch2State>': tensor(0.4217),
#  '<BattSoc>': tensor(0.6093),
#  '<ThrPosPct>': tensor(0.4382),
#  '<IntkVlvLift>': tensor(0.3618),
#  'TransGear': tensor(0.3579),
#  '<BattV>': tensor(0.4864),
#  '<Acc>': tensor(0.4758),
#  'sample': tensor(1.0139),
#  'IntkVlvLiftCmd': tensor(0.4060),
#  '<TransGear>': tensor(0.3400),
#  'BattCrnt:1': tensor(0.3049),
#  '<WgAreaPct>': tensor(0.5159),
#  'Cltch1Cmd': tensor(0.6188),
#  'MotPwrMech:1': tensor(0.3352),
#  '<xdot>': tensor(nan),
#  'FuelFlw': tensor(nan),
#  '<Chrg>': tensor(1.2733),
#  '<VarCompRatioPos>': tensor(1.3295),
#  '<EngSpd>': tensor(1.3127),
#  'StartCmd': tensor(1.2901)}

# %% [markdown]
# #EVSI

# %%
# Calculate the evoi
evoi_dict = dict()
for sensor in sensors:
    evoi_dict[sensor] = base_cost - upper_dict[sensor].item()
evoi_dict
# Out:
# {'<Cltch2State>': -0.05736064910888672,
#  '<BattSoc>': -0.24492761492729187,
#  '<ThrPosPct>': -0.0738467276096344,
#  '<IntkVlvLift>': 0.0025767087936401367,
#  'TransGear': 0.006450027227401733,
#  '<BattV>': -0.12206581234931946,
#  '<Acc>': -0.11142250895500183,
#  'sample': -0.6495296061038971,
#  'IntkVlvLiftCmd': -0.04162955284118652,
#  '<TransGear>': 0.024388551712036133,
#  'BattCrnt:1': 0.05947786569595337,
#  '<WgAreaPct>': -0.15153393149375916,
#  'Cltch1Cmd': -0.2544220983982086,
#  'MotPwrMech:1': 0.029131650924682617,
#  '<xdot>': nan,
#  'FuelFlw': nan,
#  '<Chrg>': -0.9089819490909576,
#  '<VarCompRatioPos>': -0.965152770280838,
#  '<EngSpd>': -0.9483303129673004,
#  'StartCmd': -0.9257635176181793}

# %%
sorted(evoi_dict.items(), key=lambda x: x[1], reverse= True)
# Out:
# [('BattCrnt:1', 0.05947786569595337),
#  ('MotPwrMech:1', 0.029131650924682617),
#  ('<TransGear>', 0.024388551712036133),
#  ('TransGear', 0.006450027227401733),
#  ('<IntkVlvLift>', 0.0025767087936401367),
#  ('IntkVlvLiftCmd', -0.04162955284118652),
#  ('<Cltch2State>', -0.05736064910888672),
#  ('<ThrPosPct>', -0.0738467276096344),
#  ('<Acc>', -0.11142250895500183),
#  ('<BattV>', -0.12206581234931946),
#  ('<WgAreaPct>', -0.15153393149375916),
#  ('<BattSoc>', -0.24492761492729187),
#  ('Cltch1Cmd', -0.2544220983982086),
#  ('sample', -0.6495296061038971),
#  ('<xdot>', nan),
#  ('FuelFlw', nan),
#  ('<Chrg>', -0.9089819490909576),
#  ('StartCmd', -0.9257635176181793),
#  ('<EngSpd>', -0.9483303129673004),
#  ('<VarCompRatioPos>', -0.965152770280838)]

# %%
x_1, y_1 = plot_dict(evoi_dict)
#y_1_100 = [z * 100 for z in y_1]
plt.figure(figsize=(20,10))
sns.barplot(x=x_1,y= y_1, palette = mpl.cm.ScalarMappable(cmap=sns.dark_palette("#69d", reverse=False, as_cmap=True)).to_rgba(y_1))
#plt.xticks(rotation=45);
#plt.ylim((-5.0, 16.0))
plt.title('Complete Feature Validation Accuracy Advantage')
plt.ylabel('%')
plt.xlabel('Masked Feature Name');

# %% [markdown]
# #Heatmap

# %%
plt.figure(figsize=(12, 6))

# Plot heatmap.
heatmap = np.stack([np.zeros(len(p_list[0]))] + p_list)
plt.imshow(heatmap, cmap='viridis')

# Labels.
plt.xlabel('Feature Index', fontsize=18)
plt.ylabel('# Features', fontsize=18)
plt.title('Feature Selection Frequency', fontsize=20)
plt.tick_params(labelsize=14)
cbar = plt.colorbar()
cbar.ax.tick_params(labelsize=14)
cbar.outline.set_visible(False)

plt.tight_layout()
plt.show()
